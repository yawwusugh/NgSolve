# %% [markdown]
# NGSolve Demos
# ===
#
# for Prof Harbir Antil, Rohit Khandelwal and Yaw Owusu-Agyemang

# %% [markdown]
# # 2D Problems
#
#
# ## Elliptic Problem
# ----
# * [Homogeneous dirichlet](poisson2d/Dirichlet_poisson_demo.ipynb)
# * [Boundary conditions](poisson2d/boundary_conditions.ipynb)
# * [Mixed formulation](poisson2d/mixed.ipynb)
#
#
# ## Parabolic Problem
# ----
# * [Homogeneous Dirichlet](parabolic2d/parabolic_demo.ipynb)
# * [Neumann conditions](parabolic2d/parabolic-time_demo.ipynb)

# %% [markdown]
# # 3D Problems
#
#
# ## Elliptic Problem
# ----
# * [Poisson](3d/3D_Antil_demo.ipynb)
# * [Poisson 2](3d/3D_Antil_demo_alt.ipynb)
# * [Linear Elasticity conditions](3d/elasticity3D.ipynb)

# %% [markdown]
# # Main Problem
#
#
# ## Shallow Water 2D
# ----
# * [Shallow Water](shallowH20/shallow_water.ipynb)
