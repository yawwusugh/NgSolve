# %% [markdown]
# NGSolve Demos
# ===
#
# for Prof Harbir Antil, Rohit Khandelwal and Yaw Owusu-Agyemang

# %% [markdown]
# # 2D Problems
#
#
# ## Elliptic Problem
# ----
# * [Homogeneous dirichlet](poisson2d/Dirichlet_poisson_demo.ipynb)
# * [Different Boundary conditions](poisson2d/boundary_conditions.ipynb)
# * [Mixed formulation](poisson2d/mixed.ipynb)
#
#
# ## Parabolic Problem
# ----
# * [Time Dependent RHS](parabolic2d/heat_equation-time-dep.ipynb)

# %% [markdown]
# # 3D Problems
#
#
# ## Elliptic Problem
# ----
# * [Poisson](3d/3D_Antil_demo.ipynb)
# * [Poisson 2](3d/3D_Antil_demo_alt.ipynb)
# * [Linear Elasticity example](3d/elasticity3D.ipynb)

# %% [markdown]
# # Main Problem
#
#
# ## Shallow Water 2D
# ----
# * [Shallow Water [new]](shallowH2O/shallow2D.ipynb)
# * [Shallow Water [old]](shallowH2O/shallow2D_old.ipynb)
